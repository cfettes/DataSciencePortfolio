# %%
# !python setup.py install
# Out:
# running install
# running bdist_egg
# running egg_info
# writing subpackages/instant_eda.egg-info/PKG-INFO
# writing dependency_links to subpackages/instant_eda.egg-info/dependency_links.txt
# writing entry points to subpackages/instant_eda.egg-info/entry_points.txt
# writing requirements to subpackages/instant_eda.egg-info/requires.txt
# writing top-level names to subpackages/instant_eda.egg-info/top_level.txt
# reading manifest file 'subpackages/instant_eda.egg-info/SOURCES.txt'
# reading manifest template 'MANIFEST.in'
# ...
# writing manifest file 'subpackages/instant_eda.egg-info/SOURCES.txt'
# installing library code to build/bdist.macosx-10.9-x86_64/egg
# running install_lib
# running build_py
# copying subpackages/instant_eda/version.py -> build/lib/instant_eda
# copying subpackages/instant_eda/config_interaction.yaml -> build/lib/instant_eda
# creating build/bdist.macosx-10.9-x86_64/egg
# creating build/bdist.macosx-10.9-x86_64/egg/instant_eda
# ...
